# %%
import pandas as pd
df=pd.read_csv('/home/msois/Downloads/Rainfall/southern.csv')
df
# Out:
#      YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0    1901                 155.8                 191.5                 138.4
# 1    1902                 118.9                 214.4                 159.7
# 2    1903                 141.0                 300.2                 206.2
# 3    1904                 191.9                 191.4                  89.5
# 4    1905                 153.5                 120.6                 187.6
# 5    1906                 174.0                 219.9                 221.8
# 6    1907                 184.8                 206.3                 216.3
# 7    1908                 125.0                 240.1                 155.1
# 8    1909                 157.3                 227.5                 196.0
# 9    1910                 180.0                 211.1                 209.4
# 10   1911                 189.6                 191.6                 103.5
# ...

# %%
df1=pd.read_csv('/home/msois/Downloads/Rainfall/central.csv')
df2=pd.read_csv('/home/msois/Downloads/Rainfall/northeast.csv')
df3=pd.read_csv('/home/msois/Downloads/Rainfall/northwest.csv')

# %%
import numpy as np
a=df[["Actual Rainfall: JUN","YEAR"]]
a.max()
# Out:
# Actual Rainfall: JUN     278.0
# YEAR                    2016.0
# dtype: float64

# %%
df["dry"]=df['Actual Rainfall: JUN']-df['Actual Rainfall: JUL']-df['Actual Rainfall: AUG']-df['Actual Rainfall: SEPT']

# %%
df.sort_values('dry',ascending=True)['YEAR'].head()
# Out:
# 87    1988
# 82    1983
# 61    1962
# 63    1964
# 46    1947
# Name: YEAR, dtype: int64

# %%
df2["dry"]=df2['Actual Rainfall: JUN']-df2['Actual Rainfall: JUL']-df2['Actual Rainfall: AUG']-df2['Actual Rainfall: SEPT']

# %%
df2.sort_values('dry',ascending=True)['YEAR'].head()
# Out:
# 86     1987
# 4      1905
# 106    2007
# 73     1974
# 59     1960
# Name: YEAR, dtype: int64

# %%
df3["dry"]=df3['Actual Rainfall: JUN']-df3['Actual Rainfall: JUL']-df3['Actual Rainfall: AUG']-df3['Actual Rainfall: SEPT']

# %%
df3.sort_values('dry',ascending=True)['YEAR'].head()
# Out:
# 16    1917
# 23    1924
# 7     1908
# 25    1926
# 41    1942
# Name: YEAR, dtype: int64

# %%
b=int(input("Enter the option for the region:\n1)south\n2) north-east,\n3) north-west\n4) central India\n"))
# Out:
# Enter the option for the region:
# 1)south
# 2) north-east,
# 3) north-west
# 4) central India
# 1

# %%
c=int(input("Enter the option for month\n1)jun\n2)jul\n3)aug\n4)sept\n"))
#while(b!=0):
if(b==(1 or 2 or 3 or 4 or 5)):
    if(c==1):
        print(df[["Actual Rainfall: JUN","YEAR"]].max())
    if(c==2):
        print(df1[["Actual Rainfall: JUL","YEAR"]].max())
    if(c==3):
        print(df2[["Actual Rainfall: AUG","YEAR"]].max())
    if(c==4):
        print(df3[["Actual Rainfall: SEPT","YEAR"]].max())
        #print(df["Actual Rainfall: SEPT"].max())
# Out:
# Enter the option for month
# 1)jun
# 2)jul
# 3)aug
# 4)sept
# 2
# Actual Rainfall: JUL     523.8
# YEAR                    2016.0
# dtype: float64

# %%
#df["dry"]=df['Actual Rainfall: JUN']-df['Actual Rainfall: JUL']-df['Actual Rainfall: AUG']-df['Actual Rainfall: SEPT']
#df[df[""] and df[""]=="2010"]

df[["YEAR","Actual Rainfall: JUN","Actual Rainfall: JUL","Actual Rainfall: AUG"]]
#df[df["dry"] and df["YEAR"]=="2010"]
# Out:
#      YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG
# 0    1901                 155.8                 191.5                 138.4
# 1    1902                 118.9                 214.4                 159.7
# 2    1903                 141.0                 300.2                 206.2
# 3    1904                 191.9                 191.4                  89.5
# 4    1905                 153.5                 120.6                 187.6
# 5    1906                 174.0                 219.9                 221.8
# 6    1907                 184.8                 206.3                 216.3
# 7    1908                 125.0                 240.1                 155.1
# 8    1909                 157.3                 227.5                 196.0
# 9    1910                 180.0                 211.1                 209.4
# 10   1911                 189.6                 191.6                 103.5
# ...

# %%
df["wet"]=df['Actual Rainfall: JUN']+df['Actual Rainfall: JUL']+df['Actual Rainfall: AUG']
df["wet"]
# Out:
# 0      485.7
# 1      493.0
# 2      647.4
# 3      472.8
# 4      461.7
# 5      615.7
# 6      607.4
# 7      520.2
# 8      580.8
# 9      600.5
# 10     484.7
# 11     594.7
# 12     461.5
# 13     649.6
# 14     557.8
# 15     632.2
# 16     561.6
# 17     323.6
# 18     500.6
# 19     489.0
# 20     609.1
# 21     501.4
# 22     586.7
# 23     652.4
# 24     570.7
# 25     531.1
# 26     560.2
# 27     517.9
# 28     488.4
# 29     420.7
#        ...
# 86     431.1
# 87     652.4
# 88     648.9
# 89     584.0
# 90     684.5
# 91     726.9
# 92     526.3
# 93     616.3
# 94     584.4
# 95     671.6
# 96     549.0
# 97     624.7
# 98     510.6
# 99     667.6
# 100    486.8
# 101    429.5
# 102    565.2
# 103    455.2
# 104    583.7
# 105    488.4
# 106    671.2
# 107    544.9
# 108    483.6
# 109    671.1
# 110    588.9
# 111    499.0
# 112    645.6
# 113    528.6
# 114    444.0
# 115    501.1
# Name: wet, Length: 116, dtype: float64

# %%
df1["wet"]=df1['Actual Rainfall: JUN']+df1['Actual Rainfall: JUL']+df1['Actual Rainfall: AUG']

# %%
df2["wet"]=df2['Actual Rainfall: JUN']+df2['Actual Rainfall: JUL']+df2['Actual Rainfall: AUG']

# %%
df3["wet"]=df3['Actual Rainfall: JUN']+df3['Actual Rainfall: JUL']+df3['Actual Rainfall: AUG']

# %%
df[df["wet"] and df["YEAR"]=="2010"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-7d06965d1a1f> in <module>()
# ----> 1 df[df["wet"] and df["YEAR"]=="2010"]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#     953         raise ValueError("The truth value of a {0} is ambiguous. "
#     954                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 955                          .format(self.__class__.__name__))
#     956
#     957     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd
from pandas import DataFrame
 


df = pd.read_csv('/home/msois/.cache/.fr-zMP6Xd/Rainfall')
